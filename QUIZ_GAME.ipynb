# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanahmad676/Python-Projects/blob/main/QUIZ_GAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
   Here i will create a simple math calculation quiz game for child sothat they
   can learn additaion,substarction, division,multiplication. Here we will use
   simple python code

"""



print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

print("                        WELCOME TO THE QUIZ                          ")

print("---------------------------------------------------------------------")
print("---------------------------------------------------------------------")

permission=input("Do you want to play the game! ")

if permission.lower() != "yes":
  print("Exiting the game.")
  quit()
else:
  # print(" what kind of game do you play? ")
  Game_type= input("""
                    What type of game do you want to play!
                    1. Additation.
                    2. Substarction.
                    3. Multiplication.
                    4. Division.
  """
  )

  print(Game_type)
  #ADDITATION
if Game_type == "1":
    print("welcome the additation!")
    Counter=0
    bonus=0

    Q1="what is 2+2?"
    print(Q1)
    ans=input("enter ans: ")
    if ans == str(4):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q2="what is 5+2?"
    print(Q2)
    ans=input("enter ans: ")
    if ans == str(7):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q3="what is 8+2?"
    print(Q3)
    ans=input("enter ans: ")
    if ans == str(10):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q4="what is 11+2?"
    print(Q4)
    ans=input("enter ans: ")
    if ans == str(13):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q5="what is 15+2?"
    print(Q5)
    ans=input("enter ans: ")
    if ans == str(17):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")
    print("you have got " +  str(Counter)  + " right")
    print("you have got right " + str((Counter/5)*100) + "%")
    print("you have got bonus total " + str(bonus))

# SUBSTRACTION
elif Game_type == "2":
    print("welcome the Substraction!")
    Counter=0
    bonus=0

    Q1="what is 2-2?"
    print(Q1)
    ans=input("enter ans: ")
    if ans == str(0):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q2="what is 5-2?"
    print(Q2)
    ans=input("enter ans: ")
    if ans == str(3):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q3="what is 8-2?"
    print(Q3)
    ans=input("enter ans: ")
    if ans == str(6):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q4="what is 11-2?"
    print(Q4)
    ans=input("enter ans: ")
    if ans == str(9):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q5="what is 15-2?"
    print(Q5)
    ans=input("enter ans: ")
    if ans == str(13):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")
    print("you have got " +  str(Counter)  + " right")
    print("you have got right " + str((Counter/5)*100) + "%")
    print("you have got bonus total " + str(bonus))

#multiplication
elif Game_type == "3":
    print("welcome the multiplication!")
    Counter=0
    bonus=0

    Q1="what is 2*2?"
    print(Q1)
    ans=input("enter ans: ")
    if ans == str(4):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q2="what is 5*2?"
    print(Q2)
    ans=input("enter ans: ")
    if ans == str(10):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q3="what is 8*2?"
    print(Q3)
    ans=input("enter ans: ")
    if ans == str(16):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q4="what is 11*2?"
    print(Q4)
    ans=input("enter ans: ")
    if ans == str(22):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q5="what is 15*2?"
    print(Q5)
    ans=input("enter ans: ")
    if ans == str(30):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")
    print("you have got " +  str(Counter)  + " right")
    print("you have got right " + str((Counter/5)*100) + "%")
    print("you have got bonus total " + str(bonus))


#DIVISION
elif Game_type == "4":
    print("welcome the additation!")
    Counter=0
    bonus=0

    Q1="what is 2/2?"
    print(Q1)
    ans=input("enter ans: ")
    if ans == str(1):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q2="what is 4/2?"
    print(Q2)
    ans=input("enter ans: ")
    if ans == str(2):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q3="what is 8/2?"
    print(Q3)
    ans=input("enter ans: ")
    if ans == str(4):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q4="what is 12/6?"
    print(Q4)
    ans=input("enter ans: ")
    if ans == str(2):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")

    Q5="what is 18/2?"
    print(Q5)
    ans=input("enter ans: ")
    if ans == str(9):
      print("you're right")
      Counter+=1
      bonus+=10

    else:
      print("wrong answer")
    print("you have got " +  str(Counter)  + " right")
    print("you have got right " + str((Counter/5)*100) + "%")
    print("you have got bonus total " + str(bonus))
# Out:
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
#                         WELCOME TO THE QUIZ
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Do you want to play the game! yes
#
#                     What type of game do you want to play!
#                     1. Additation.
#                     2. Substarction.
#                     3. Multiplication.
#                     4. Division.
#   3
# 3
# welcome the multiplication!
# what is 2*2?
# enter ans: 4
# you're right
# what is 5*2?
# enter ans: 10
# you're right
# what is 8*2?
# enter ans: 16
# you're right
# what is 11*2?
# enter ans: 22
# you're right
# what is 15*2?
# enter ans: 30
# you're right
# you have got 5 right
# you have got right 100.0%
# you have got bonus total 50
